# %% [markdown]
# ### Library Imports

# %%
import pandas as pd # type: ignore

# %% [markdown]
# ### Load Dataset

# %%
df = pd.read_csv('../datasets/features_30_sec.csv') # Path del dataset
df = df.iloc[1:, 2:] 
df.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 1          0.340914         0.094980  0.095948  0.002373
# 2          0.363637         0.085275  0.175570  0.002746
# 3          0.404785         0.093999  0.141093  0.006346
# 4          0.308526         0.087841  0.091529  0.002303
# 5          0.302456         0.087532  0.103494  0.003981
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 1             1530.176679           3.758501e+05              2039.036516
# 2             1552.811865           1.564676e+05              1747.702312
# 3             1070.106615           1.843559e+05              1596.412872
# 4             1835.004266           3.433999e+05              1748.172116
# 5             1831.993940           1.030482e+06              1729.653287
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_var  \
# 1           213843.755497   3550.522098  2.977893e+06  ...   55.356403
# ...

# %% [markdown]
# ### Notebook Exports

# %%
import pickle

with open('pkl/df.pkl', 'wb') as f:
    pickle.dump(df, f)
